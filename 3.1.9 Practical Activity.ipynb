# %% [markdown]
# ## Practical activity: Use groupby() and aggregate() functions

# %% [markdown]
# # 3.1.9 Practical Activty

# %%
# Import Pandas.
import pandas as pd

# %%
# Load the Excel and CSV files
movies = pd.read_excel('movies_merge.xlsx')
ott = pd.read_csv('ott_merge.csv')

# %%
# Merge the two DataFrames.
mov_ott = pd.merge(movies, ott, how='left', on = 'ID')

# %%
# Check DataFrames merged correctly
print(mov_ott.columns)
print(mov_ott.shape)
# Out:
# Index(['ID', 'Title', 'Year', 'Age', 'IMDb', 'Rotten Tomatoes', 'Directors',
#        'Genres', 'Country', 'Language', 'Runtime', 'Netflix', 'Hulu',
#        'Prime Video', 'Disney+'],
#       dtype='object')
# (16744, 15)

# %%
mov_ott
# Out:
#           ID                           Title  Year  Age  IMDb  \
# 0          1                       Inception  2010  13+   8.8
# 1          2                      The Matrix  1999  18+   8.7
# 2          3          Avengers: Infinity War  2018  13+   8.5
# 3          4              Back to the Future  1985   7+   8.5
# 4          5  The Good, the Bad and the Ugly  1966  18+   8.8
# ...      ...                             ...   ...  ...   ...
# 16739  16740       The Ghosts of Buxley Hall  1980  NaN   6.2
# 16740  16741                  The Poof Point  2001   7+   4.7
# 16741  16742           Sharks of Lost Island  2013  NaN   5.7
# 16742  16743              Man Among Cheetahs  2017  NaN   6.6
# 16743  16744                In Beaver Valley  1950  NaN   NaN
#
#        Rotten Tomatoes                       Directors  \
# 0                 0.87               Christopher Nolan
# 1                 0.87  Lana Wachowski,Lilly Wachowski
# ...

# %% [markdown]
# # Q1: How many films from each year (released from 2012 to the present) were watched on Netflix?

# %%
# Determine the number of movies watched on Netflix since 2012.
mo_gpby = mov_ott.groupby(['Year'])['Netflix'].agg('sum').reset_index()
mo_gpby[mo_gpby['Year'] >= 2012]
# Out:
#      Year  Netflix
# 100  2012      195
# 101  2013      200
# 102  2014      202
# 103  2015      252
# 104  2016      236
# 105  2017      294
# 106  2018      307
# 107  2019      138
# 108  2020       31

# %%
# Practise again

# %%
# mov_grp is name for new groupby DF

# %%
mo_grp = mov_ott.groupby(['Year'])['Netflix'].agg('sum').reset_index()

# %%
# Prune it down to only films released from 2012 and onwards

# %%
mo_grp[mo_grp['Year'] >= 2012]
# Out:
#      Year  Netflix
# 100  2012      195
# 101  2013      200
# 102  2014      202
# 103  2015      252
# 104  2016      236
# 105  2017      294
# 106  2018      307
# 107  2019      138
# 108  2020       31

# %% [markdown]
# # Q2 Mean length of films each year

# %%
# Create a new DF to hold the groupby data

# %%
mo_runtim = mov_ott.groupby(['Year'])['Runtime'].agg('mean').reset_index()

# %%
# Filter on films released from 2012 and onwards

# %%
mo_runtim[mo_runtim['Year'] >=2012]
# Out:
#      Year    Runtime
# 100  2012  90.511714
# 101  2013  91.545940
# 102  2014  92.995763
# 103  2015  92.914646
# 104  2016  93.992140
# 105  2017  94.460961
# 106  2018  94.635678
# 107  2019  93.410413
# 108  2020  93.976562

# %% [markdown]
# # Q3 Find min() and max() Rotten Tomatoe values 2012 onwards

# %%
# Create new DF called mo_tom to hold groupby data

# %%
mo_tom = mov_ott.groupby(['Year'])['Rotten Tomatoes'].agg(['max', 'min']).reset_index()

# %%
mo_tom[mo_tom['Year'] >=2012]
# Out:
#      Year  max   min
# 100  2012  1.0  0.04
# 101  2013  1.0  0.02
# 102  2014  1.0  0.05
# 103  2015  1.0  0.05
# 104  2016  1.0  0.02
# 105  2017  1.0  0.04
# 106  2018  1.0  0.06
# 107  2019  1.0  0.05
# 108  2020  1.0  0.06
